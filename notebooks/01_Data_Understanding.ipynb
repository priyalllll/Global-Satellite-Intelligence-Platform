# %%
# ============================================================
# Global Satellite Intelligence Platform (GSIP)
# Notebook: 01_Data_Understanding.ipynb
# Author: Priyal Rathore
# Description:
# Initial exploration and understanding of the
# UCS Satellite Database.
# ============================================================

# %%
import pandas as pd
import numpy as np

# %%
file_path = "../data/raw/UCS-Satellite-Database 5-1-2023.xlsx"

# %%
import pandas as pd

excel_file = pd.ExcelFile(r"C:\Global-Satellite-Intelligence-Platform\data\raw\UCS-Satellite-Database 5-1-2023.xlsx")

print("Worksheets:")
print(excel_file.sheet_names)
# Out:
# Worksheets:
# ['Sheet1', 'Sheet2', 'Sheet3']

# %%
# Read the first worksheet containing the satellite data
df = pd.read_excel(excel_file, sheet_name="Sheet1")

# %%
df.head()
# Out:
#                   Name of Satellite, Alternate Names  \
# 0  1HOPSAT-TD (1st-generation High Optical Perfor...
# 1                            AAC AIS-Sat1 (Kelpie 1)
# 2                                           Aalto-1
# 3                                              AAt-4
# 4                           ABS-2 (Koreasat-8, ST-3)
#
#   Current Official Name of Satellite Country/Org of UN Registry  \
# 0                         1HOPSAT-TD                         NR
# 1            AAC AIS-Sat1 (Kelpie 1)             United Kingdom
# 2                            Aalto-1                    Finland
# 3                              AAt-4                    Denmark
# 4                              ABS-2                         NR
#
#   Country of Operator/Owner                 Operator/Owner       Users  \
# 0                       USA                   Hera Systems  Commercial
# 1            United Kingdom                AAC Clyde Space  Commercial
# ...

# %%
df.tail()
# Out:
#      Name of Satellite, Alternate Names Current Official Name of Satellite  \
# 7555                       Ziyuan 1-02C                       Ziyuan 1-02C
# 7556                        Ziyuan 1-2D                        Ziyuan 1-2D
# 7557                    Ziyuan 3 (ZY-3)                           Ziyuan 3
# 7558                         Ziyuan 3-2                         Ziyuan 3-2
# 7559                         Ziyuan 3-3                         Ziyuan 3-3
#
#      Country/Org of UN Registry Country of Operator/Owner  \
# 7555                      China                     China
# 7556                         NR                     China
# 7557                      China                     China
# 7558                      China                     China
# 7559                      China                     China
#
#                                          Operator/Owner       Users  \
# 7555  China Centre for Resources Satellite Data and ...  Government
# ...

# %%
print("=" * 40)
print("DATASET DIMENSIONS")
print("=" * 40)

rows, columns = df.shape

print(f"Number of Rows    : {rows}")
print(f"Number of Columns : {columns}")
# Out:
# ...
# DATASET DIMENSIONS
# ...
# Number of Rows    : 7560
# Number of Columns : 68

# %%
print("=" * 40)
print("COLUMN NAMES")
print("=" * 40)

for index, column in enumerate(df.columns, start=1):
    print(f"{index}. {column}")
# Out:
# ...
# COLUMN NAMES
# ...
# 1. Name of Satellite, Alternate Names
# 2. Current Official Name of Satellite
# 3. Country/Org of UN Registry
# 4. Country of Operator/Owner
# 5. Operator/Owner
# 6. Users
# 7. Purpose
# 8. Detailed Purpose
# 9. Class of Orbit
# 10. Type of Orbit
# 11. Longitude of GEO (degrees)
# 12. Perigee (km)
# 13. Apogee (km)
# 14. Eccentricity
# 15. Inclination (degrees)
# 16. Period (minutes)
# 17. Launch Mass (kg.)
# 18. Dry Mass (kg.)
# 19. Power (watts)
# 20. Date of Launch
# 21. Expected Lifetime (yrs.)
# 22. Contractor
# 23. Country of Contractor
# 24. Launch Site
# 25. Launch Vehicle
# 26. COSPAR Number
# 27. NORAD Number
# 28. Comments
# 29. Unnamed: 28
# 30. Source Used for Orbital Data
# 31. Source
# 32. Source.1
# 33. Source.2
# 34. Source.3
# 35. Source.4
# 36. Source.5
# 37. Source.6
# 38. Unnamed: 37
# 39. Unnamed: 38
# 40. Unnamed: 39
# 41. Unnamed: 40
# 42. Unnamed: 41
# 43. Unnamed: 42
# 44. Unnamed: 43
# 45. Unnamed: 44
# 46. Unnamed: 45
# 47. Unnamed: 46
# ...

# %%
print("=" * 40)
print("DATA TYPES")
print("=" * 40)

df.dtypes
# Out:
# ...
# DATA TYPES
# ...
# Name of Satellite, Alternate Names    object
# Current Official Name of Satellite    object
# Country/Org of UN Registry            object
# Country of Operator/Owner             object
# Operator/Owner                        object
#                                        ...
# Unnamed: 63                           object
# Unnamed: 64                           object
# Unnamed: 65                           object
# Unnamed: 66                           object
# Unnamed: 67                           object
# Length: 68, dtype: object

# %%
print("=" * 40)
print("DATASET INFORMATION")
print("=" * 40)

df.info()
# Out:
# ...
# DATASET INFORMATION
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7560 entries, 0 to 7559
# Data columns (total 68 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Name of Satellite, Alternate Names  7560 non-null   object
#  1   Current Official Name of Satellite  7560 non-null   object
#  2   Country/Org of UN Registry          7559 non-null   object
#  3   Country of Operator/Owner           7560 non-null   object
#  4   Operator/Owner                      7560 non-null   object
#  5   Users                               7560 non-null   object
#  6   Purpose                             7560 non-null   object
#  7   Detailed Purpose                    1254 non-null   object
#  8   Class of Orbit                      7560 non-null   object
#  9   Type of Orbit                       6909 non-null   object
#  10  Longitude of GEO (degrees)          7557 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Longitude of GEO (degrees)  Perigee (km)    Apogee (km)  Eccentricity  \
# count                 7557.000000   7553.000000    7553.000000   7549.000000
# mean                     1.704567   3703.945187    4236.369390      0.480882
# std                     26.292065   9715.789212   13123.003517     15.567178
# min                   -179.800000    150.000000      49.000000     -0.033429
# 25%                      0.000000    521.000000     536.000000      0.000199
# 50%                      0.000000    548.000000     561.000000      0.000297
# 75%                      0.000000    600.000000     626.000000      0.000939
# max                    359.000000  62200.000000  353798.000000    575.000000
#
#        Inclination (degrees)  Period (minutes)  Launch Mass (kg.)  \
# count            7556.000000       7504.000000        7315.000000
# mean               62.534161        224.016189         626.321319
# std                27.236581        441.495461        1386.207982
# ...

# %%
df.describe(include="all")
# Out:
#                        Name of Satellite, Alternate Names  \
# count                                                7560
# unique                                               7543
# top     SB-WASS 3-5 (Space Based Wide Area Surveillanc...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Current Official Name of Satellite Country/Org of UN Registry  \
# count                                7560                       7559
# unique                               7530                         69
# ...

# %%
for i, column in enumerate(df.columns, start=1):
    print(f"{i}. {column}")
# Out:
# 1. Name of Satellite, Alternate Names
# 2. Current Official Name of Satellite
# 3. Country/Org of UN Registry
# 4. Country of Operator/Owner
# 5. Operator/Owner
# 6. Users
# 7. Purpose
# 8. Detailed Purpose
# 9. Class of Orbit
# 10. Type of Orbit
# 11. Longitude of GEO (degrees)
# 12. Perigee (km)
# 13. Apogee (km)
# 14. Eccentricity
# 15. Inclination (degrees)
# 16. Period (minutes)
# 17. Launch Mass (kg.)
# 18. Dry Mass (kg.)
# 19. Power (watts)
# 20. Date of Launch
# 21. Expected Lifetime (yrs.)
# 22. Contractor
# 23. Country of Contractor
# 24. Launch Site
# 25. Launch Vehicle
# 26. COSPAR Number
# 27. NORAD Number
# 28. Comments
# 29. Unnamed: 28
# 30. Source Used for Orbital Data
# 31. Source
# 32. Source.1
# 33. Source.2
# 34. Source.3
# 35. Source.4
# 36. Source.5
# 37. Source.6
# 38. Unnamed: 37
# 39. Unnamed: 38
# 40. Unnamed: 39
# 41. Unnamed: 40
# 42. Unnamed: 41
# 43. Unnamed: 42
# 44. Unnamed: 43
# 45. Unnamed: 44
# 46. Unnamed: 45
# 47. Unnamed: 46
# 48. Unnamed: 47
# ...

# %%
# Create a DataFrame of all column names
columns_df = pd.DataFrame({
    "Column Number": range(1, len(df.columns) + 1),
    "Column Name": df.columns
})

columns_df
# Out:
#     Column Number                         Column Name
# 0               1  Name of Satellite, Alternate Names
# 1               2  Current Official Name of Satellite
# 2               3          Country/Org of UN Registry
# 3               4           Country of Operator/Owner
# 4               5                      Operator/Owner
# ..            ...                                 ...
# 63             64                         Unnamed: 63
# 64             65                         Unnamed: 64
# 65             66                         Unnamed: 65
# 66             67                         Unnamed: 66
# 67             68                         Unnamed: 67
#
# [68 rows x 2 columns]

# %%
columns_df.to_csv("../docs/column_names.csv", index=False)

print("Column names exported successfully!")
# Out:
# Column names exported successfully!

# %%
print("=" * 50)
print("DATASET SHAPE")
print("=" * 50)

print(f"Rows    : {df.shape[0]}")
print(f"Columns : {df.shape[1]}")
# Out:
# ...
# DATASET SHAPE
# ...
# Rows    : 7560
# Columns : 68

# %%
print("=" * 50)
print("MISSING VALUES")
print("=" * 50)

missing_values = df.isnull().sum()

missing_df = pd.DataFrame({
    "Column": df.columns,
    "Missing Values": missing_values,
    "Missing Percentage": round((missing_values / len(df)) * 100, 2)
})

missing_df = missing_df.sort_values(
    by="Missing Values",
    ascending=False
)

missing_df
# Out:
# ...
# MISSING VALUES
# ...
#                       Column  Missing Values  Missing Percentage
# Unnamed: 28      Unnamed: 28            7555               99.93
# Unnamed: 50      Unnamed: 50            7076               93.60
# Unnamed: 51      Unnamed: 51            7076               93.60
# Unnamed: 49      Unnamed: 49            7076               93.60
# Unnamed: 52      Unnamed: 52            7076               93.60
# ...                      ...             ...                 ...
# Contractor        Contractor               0                0.00
# COSPAR Number  COSPAR Number               0                0.00
# NORAD Number    NORAD Number               0                0.00
# Users                  Users               0                0.00
# Purpose              Purpose               0                0.00
#
# [68 rows x 3 columns]

# %%
print("=" * 50)
print("DUPLICATE RECORDS")
print("=" * 50)

duplicates = df.duplicated().sum()

print(f"Duplicate Rows: {duplicates}")
# Out:
# ...
# DUPLICATE RECORDS
# ...
# Duplicate Rows: 7

# %%
unique_df = pd.DataFrame({
    "Column": df.columns,
    "Unique Values": df.nunique()
})

unique_df
# Out:
#                                                                 Column  \
# Name of Satellite, Alternate Names  Name of Satellite, Alternate Names
# Current Official Name of Satellite  Current Official Name of Satellite
# Country/Org of UN Registry                  Country/Org of UN Registry
# Country of Operator/Owner                    Country of Operator/Owner
# Operator/Owner                                          Operator/Owner
# ...                                                                ...
# Unnamed: 63                                                Unnamed: 63
# Unnamed: 64                                                Unnamed: 64
# Unnamed: 65                                                Unnamed: 65
# Unnamed: 66                                                Unnamed: 66
# Unnamed: 67                                                Unnamed: 67
#
#                                     Unique Values
# Name of Satellite, Alternate Names           7543
# ...

# %%
dtype_summary = df.dtypes.value_counts()

print(dtype_summary)
# Out:
# object     59
# float64     8
# int64       1
# Name: count, dtype: int64

# %%
memory = df.memory_usage(deep=True).sum() / (1024 ** 2)

print(f"Memory Usage: {memory:.2f} MB")
# Out:
# Memory Usage: 19.58 MB

# %%
numeric_summary = df.describe()

numeric_summary
# Out:
#        Longitude of GEO (degrees)  Perigee (km)    Apogee (km)  Eccentricity  \
# count                 7557.000000   7553.000000    7553.000000   7549.000000
# mean                     1.704567   3703.945187    4236.369390      0.480882
# std                     26.292065   9715.789212   13123.003517     15.567178
# min                   -179.800000    150.000000      49.000000     -0.033429
# 25%                      0.000000    521.000000     536.000000      0.000199
# 50%                      0.000000    548.000000     561.000000      0.000297
# 75%                      0.000000    600.000000     626.000000      0.000939
# max                    359.000000  62200.000000  353798.000000    575.000000
#
#        Inclination (degrees)  Period (minutes)  Launch Mass (kg.)  \
# count            7556.000000       7504.000000        7315.000000
# mean               62.534161        224.016189         626.321319
# std                27.236581        441.495461        1386.207982
# ...

# %%
categorical_summary = df.describe(include="object")

categorical_summary
# Out:
#                        Name of Satellite, Alternate Names  \
# count                                                7560
# unique                                               7543
# top     SB-WASS 3-5 (Space Based Wide Area Surveillanc...
# freq                                                    2
#
#        Current Official Name of Satellite Country/Org of UN Registry  \
# count                                7560                       7559
# unique                               7530                         69
# top                               Jilin-1                        USA
# freq                                    5                       4991
#
#        Country of Operator/Owner Operator/Owner       Users         Purpose  \
# count                       7560           7560        7560            7560
# unique                       105            668          20              31
# top                          USA         SpaceX  Commercial  Communications
# ...

# %%
missing_df.to_csv(
    "../reports/data_profile_summary.csv",
    index=False
)

print("Data profile report saved successfully.")
# Out:
# Data profile report saved successfully.

# %%
missing_df.head(20)
# Out:
#                   Column  Missing Values  Missing Percentage
# Unnamed: 28  Unnamed: 28            7555               99.93
# Unnamed: 50  Unnamed: 50            7076               93.60
# Unnamed: 51  Unnamed: 51            7076               93.60
# Unnamed: 49  Unnamed: 49            7076               93.60
# Unnamed: 52  Unnamed: 52            7076               93.60
# Unnamed: 43  Unnamed: 43            7076               93.60
# Unnamed: 41  Unnamed: 41            7076               93.60
# Unnamed: 42  Unnamed: 42            7076               93.60
# Unnamed: 47  Unnamed: 47            7076               93.60
# Unnamed: 46  Unnamed: 46            7076               93.60
# Unnamed: 45  Unnamed: 45            7076               93.60
# Unnamed: 48  Unnamed: 48            7076               93.60
# Unnamed: 44  Unnamed: 44            7076               93.60
# Unnamed: 39  Unnamed: 39            7076               93.60
# ...

# %%
dtype_summary
# Out:
# object     59
# float64     8
# int64       1
# Name: count, dtype: int64
